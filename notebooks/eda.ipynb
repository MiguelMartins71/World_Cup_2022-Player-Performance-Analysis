# %%
import pandas as pd

# %%
df_defensiveplayers = pd.read_csv('../data/raw/player_defense.csv')
df_keepers = pd.read_csv('../data/raw/player_defense.csv')
df_passing = pd.read_csv('../data/raw/player_passing.csv')
df_keepers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 680 entries, 0 to 679
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   player                 680 non-null    object
#  1   position               680 non-null    object
#  2   team                   680 non-null    object
#  3   age                    680 non-null    object
#  4   birth_year             680 non-null    int64
#  5   minutes_90s            680 non-null    float64
#  6   tackles                677 non-null    float64
#  7   tackles_won            680 non-null    int64
#  8   tackles_def_3rd        677 non-null    float64
#  9   tackles_mid_3rd        677 non-null    float64
#  10  tackles_att_3rd        677 non-null    float64
#  11  dribble_tackles        677 non-null    float64
#  12  dribbles_vs            677 non-null    float64
#  13  dribble_tackles_pct    483 non-null    float64
# ...

# %%
df_defensiveplayers.head()
# Out:
#                  player position       team     age  birth_year  minutes_90s  \
# 0            Aaron Mooy       MF  Australia  32-094        1990          4.0
# 1          Aaron Ramsey       MF      Wales  31-357        1990          3.0
# 2     Abdelhamid Sabiri       MF    Morocco  26-020        1996          2.0
# 3     Abdelkarim Hassan       DF      Qatar  29-112        1993          3.0
# 4  Abderrazak Hamdallah       FW    Morocco  32-001        1990          0.8
#
#    tackles  tackles_won  tackles_def_3rd  tackles_mid_3rd  ...  dribbles_vs  \
# 0      9.0            6              4.0              4.0  ...          8.0
# 1      2.0            0              0.0              2.0  ...          2.0
# 2      3.0            1              1.0              2.0  ...          6.0
# 3      7.0            3              5.0              2.0  ...          4.0
# 4      0.0            0              0.0              0.0  ...          1.0
#
# ...
